# %% [markdown]
# Colab 에서 사용

# %%
# 한글 폰트 설치하기 (꼭! 설치가 완료되면 [런타임 다시 시작]을 누르고 다시 실행하기)
# !apt install fonts-nanum -y

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 한글 폰트 설정하기
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=10)
plt.rc('font', family='NanumBarunGothic')
matplotlib.font_manager._rebuild()
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# The following packages were automatically installed and are no longer required:
#   libnvidia-common-460 nsight-compute-2020.2.0
# Use 'apt autoremove' to remove them.
# 0 upgraded, 0 newly installed, 0 to remove and 42 not upgraded.

# %%
# !pip install bing_image_downloader

# %%
import os
import shutil
from bing_image_downloader import downloader

# %%
from google.colab import drive
drive.mount('/content/mount')
# Out:
# Drive already mounted at /content/mount; to attempt to forcibly remount, call drive.mount("/content/mount", force_remount=True).

# %%
# 구글 드라이브에 clone 해놓은 IMG 리포지터리로 이동
# %cd /content/mount/MyDrive/Colab_Notebooks/Git/Commit_folder/IMG
# Out:
# /content/mount/MyDrive/Colab_Notebooks/Git/Commit_folder/IMG

# %%
# data를 담을 폴더가 없으면 생성
if not os.path.isdir('data'):
    os.makedirs('data')

# %%
# data 폴더로 들어감
# %cd data
# Out:
# /content/mount/MyDrive/Colab_Notebooks/Git/Commit_folder/IMG/data

# %%
# 쌀밥 사진 300장 크롤링
query = '쌀밥'
downloader.download(query, limit=300, output_dir='./', adult_filter_off=True, force_replace=False, timeout=60)

# %%
# 계란후라이 사진 300장 크롤링
query = '계란후라이'
downloader.download(query, limit=300, output_dir='./', adult_filter_off=True, force_replace=False, timeout=60)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# [!!]Indexing page: 331
#
# [%] Indexed 15 Images on Page 331.
#
# ...
#
#
#
# [!!]Indexing page: 332
#
# [%] Indexed 15 Images on Page 332.
#
# ...
#
#
#
# [!!]Indexing page: 333
#
# [%] Indexed 15 Images on Page 333.
#
# ...
#
#
#
# [!!]Indexing page: 334
#
# [%] Indexed 15 Images on Page 334.
#
# ...
#
#
#
# [!!]Indexing page: 335
#
# [%] Indexed 15 Images on Page 335.
#
# ...
#
#
#
# [!!]Indexing page: 336
#
# [%] Indexed 15 Images on Page 336.
#
# ...
#
#
#
# [!!]Indexing page: 337
#
# [%] Indexed 16 Images on Page 337.
#
# ...
#
#
#
# [!!]Indexing page: 338
#
# [%] Indexed 15 Images on Page 338.
#
# ...
#
#
#
# [!!]Indexing page: 339
#
# [%] Indexed 18 Images on Page 339.
#
# ...
#
#
#
# [!!]Indexing page: 340
#
# [%] Indexed 18 Images on Page 340.
#
# ...
#
#
#
# [!!]Indexing page: 341
#
# [%] Indexed 16 Images on Page 341.
#
# ...
#
#
#
# [!!]Indexing page: 342
#
# [%] Indexed 8 Images on Page 342.
#
# ...
#
#
#
# [!!]Indexing page: 343
#
# [%] Indexed 15 Images on Page 343.
#
# ...
#
#
#
# [!!]Indexing page: 344
#
# ...

# %%
# 계란말이 사진 300장 크롤링
query = '계란말이'
downloader.download(query, limit=300, output_dir='./', adult_filter_off=True, force_replace=False, timeout=60)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#
# [!!]Indexing page: 671
#
# [%] Indexed 17 Images on Page 671.
#
# ...
#
#
#
# [!!]Indexing page: 672
#
# [%] Indexed 17 Images on Page 672.
#
# ...
#
#
#
# [!!]Indexing page: 673
#
# [%] Indexed 17 Images on Page 673.
#
# ...
#
#
#
# [!!]Indexing page: 674
#
# [%] Indexed 17 Images on Page 674.
#
# ...
#
#
#
# [!!]Indexing page: 675
#
# [%] Indexed 16 Images on Page 675.
#
# ...
#
#
#
# [!!]Indexing page: 676
#
# [%] Indexed 17 Images on Page 676.
#
# ...
#
#
#
# [!!]Indexing page: 677
#
# [%] Indexed 17 Images on Page 677.
#
# ...
#
#
#
# [!!]Indexing page: 678
#
# [%] Indexed 17 Images on Page 678.
#
# ...
#
#
#
# [!!]Indexing page: 679
#
# [%] Indexed 8 Images on Page 679.
#
# ...
#
#
#
# [!!]Indexing page: 680
#
# [%] Indexed 17 Images on Page 680.
#
# ...
#
#
#
# [!!]Indexing page: 681
#
# [%] Indexed 17 Images on Page 681.
#
# ...
#
#
#
# [!!]Indexing page: 682
#
# [%] Indexed 18 Images on Page 682.
#
# ...
#
#
#
# [!!]Indexing page: 683
#
# [%] Indexed 8 Images on Page 683.
#
# ...
#
#
#
# [!!]Indexing page: 684
# ...
