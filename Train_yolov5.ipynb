# %%
import os
from glob import glob
import yaml
import shutil
from IPython.display import Image

# %%
from google.colab import drive
drive.mount('/content/mount')
# Out:
# Mounted at /content/mount

# %%
# %cd /content/mount/MyDrive/Colab_Notebooks/Git/Commit_folder/IMG
# Out:
# /content/mount/MyDrive/Colab_Notebooks/Git/Commit_folder/IMG

# %%
img_folder_list = glob('./data/images/*')
img_list = []
for img_folder in img_folder_list:
    img_list += glob(img_folder + '/*.jpg')
len(img_list)
# Out:
# 4303

# %%
from sklearn.model_selection import train_test_split

train_img_list, val_img_list = train_test_split(img_list, test_size=0.2, random_state=129)

print(len(train_img_list), len(val_img_list))
# Out:
# 3442 861

# %%
if not os.path.isdir('/content/mount/MyDrive/Colab_Notebooks/Git/Commit_folder/yolov5/dataset'):
    os.makedirs('/content/mount/MyDrive/Colab_Notebooks/Git/Commit_folder/yolov5/dataset')

# %%
with open('/content/mount/MyDrive/Colab_Notebooks/Git/Commit_folder/yolov5/dataset/train.txt', 'w') as f :
  f.write('\n'.join(train_img_list) + '\n')

with open('/content/mount/MyDrive/Colab_Notebooks/Git/Commit_folder/yolov5/dataset/val.txt', 'w') as f:
  f.write('\n'.join(val_img_list) + '\n')

# %%
# !pip install pyyaml==5.4.1

# %%
import yaml

with open('/content/mount/MyDrive/Colab_Notebooks/Git/Commit_folder/IMG/data/data.yaml', 'r') as f:
  data = yaml.load(f)

print(data)

data['train'] = '/content/mount/MyDrive/Colab_Notebooks/Git/Commit_folder/yolov5/dataset/train.txt'
data['val'] = '/content/mount/MyDrive/Colab_Notebooks/Git/Commit_folder/yolov5/dataset/val.txt'

with open('/content/mount/MyDrive/Colab_Notebooks/Git/Commit_folder/IMG/data/data.yaml', 'w') as f:
  yaml.dump(data, f)
print(data)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   after removing the cwd from sys.path.
# {'names': ['jabgogbab', 'baechugimchi', 'doenjangjjigae', 'gimchijjigae', 'myeolchibokk-eum', 'Sigeumchinamul', 'gajinamul', 'gosalinamul', 'miyeoggug', 'gimbab', 'bulgogi', 'aehobagbokk-eum', 'musaengchae', 'jabchae', 'mugug', 'godeung-eogu-i', 'ssalbab', 'gyelanhulai', 'gyelanmal-i'], 'nc': 19, 'train': '/content/mount/MyDrive/Colab_Notebooks/Git/Commit_folder/yolov5/dataset/train.txt', 'val': '/content/mount/MyDrive/Colab_Notebooks/Git/Commit_folder/yolov5/dataset/val.txt'}
# ...

# %%
# time
# %cd /content/mount/MyDrive/Colab_Notebooks/Git/Commit_folder/yolov5
# !python train.py --img 416 --batch 16 --epochs 3 --data /content/mount/MyDrive/Colab_Notebooks/Git/Commit_folder/IMG/data/data.yaml --cfg /content/mount/MyDrive/Colab_Notebooks/Git/Commit_folder/yolov5/models/yolov5s.yaml --weights yolov5s.pt --name food_yolov5s_results
# Out:
# /content/mount/MyDrive/Colab_Notebooks/Git/Commit_folder/yolov5
# train: weights=yolov5s.pt, cfg=/content/mount/MyDrive/Colab_Notebooks/Git/Commit_folder/yolov5/models/yolov5s.yaml, data=/content/mount/MyDrive/Colab_Notebooks/Git/Commit_folder/IMG/data/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=food_yolov5s_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# Command 'git fetch && git config --get remote.origin.url' timed out after 5 seconds
# YOLOv5 🚀 v6.1-196-g614ef11 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# ...
